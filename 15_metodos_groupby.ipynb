# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosramos1/numpy-pandas-matplotlib/blob/main/15_metodos_groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime

pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ## El método ```pd.DataFrame.groupby()```.
#
# Permite agrupar filas según un criterio.
#
# ```
# <df>.groupby(by=<criterio>)
# ```
#
# * ```criterio``` de agrupación, puede ser:
#   - un objeto `str` que corresponda algún identificador.
#   - una lista de `str` con identificadores.
#   - Además de otros tipos, *ver documentación*.
#
# Este método regresa un objeto de tipo ```pd.core.groupby.generic.DataFrameGroupBy```, el cual contiene varios métodos para operar con los grupos (ver ejemplos).
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %% [markdown]
# **Ejemplo:**

# %%
ventas = pd.DataFrame({
  'clientes':('CL-58', 'CL-24','CL-33', 'CL-58','CL-33', 'CL-58'),
  'monto':   (1420.00, 1532.00, 890.00, 1300.00, 3121.47, 1100.5),
                      })
ventas
# Out:
#   clientes    monto
# 0    CL-58  1420.00
# 1    CL-24  1532.00
# 2    CL-33   890.00
# 3    CL-58  1300.00
# 4    CL-33  3121.47
# 5    CL-58  1100.50

# %%
# Agrupar por la columna "clientes"
clientes = ventas.groupby("clientes")
clientes  # <-- es de tipo pd.core.groupby.generic.DataFrameGroupBy.

# %% [markdown]
# ### Los objetos ```core.groupby.generic.DataFrameGroupBy```.
#
# Son iteradores que contienen a objetos de tipo ```tuple``` resultantes de la agrupación.
#
# Dichos objetos contiene diversos métodos capaces de procesar los datos de cada grupo.

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * Las siguientes celdas mostrarán algunos métodos y atributos de los objetos ```core.groupby.generic.DataFrameGroupBy```.

# %%
# Cantidad de elementos por grupo
clientes.size()
# Out:
# clientes
# CL-24    1
# CL-33    2
# CL-58    3
# dtype: int64

# %%
clientes.mean()
# Out:
#              monto
# clientes
# CL-24     1532.000
# CL-33     2005.735
# CL-58     1273.500

# %%
clientes.max()
# Out:
#             monto
# clientes
# CL-24     1532.00
# CL-33     3121.47
# CL-58     1420.00

# %%
clientes.min()
# Out:
#            monto
# clientes
# CL-24     1532.0
# CL-33      890.0
# CL-58     1100.5

# %%
clientes.sum()
# Out:
#             monto
# clientes
# CL-24     1532.00
# CL-33     4011.47
# CL-58     3820.50

# %%
# Otros métodos disponibles
dir(clientes)
# Out:
# ['_DataFrameGroupBy__examples_dataframe_doc',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_agg_examples_doc',
#  '_agg_general',
#  '_agg_py_fallback',
#  '_aggregate_frame',
#  '_aggregate_with_numba',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_ascending_count',
#  '_cache',
#  '_choose_path',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_general',
# ...
